# %%
import numpy as np
import os
from Curvas import Curve
from Curvas import import_measured_curves, import_calculated_curves, print_curve_data
from typing import List
import copy
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly as px

# measurement_file_path = r'P:\8 - Físicos Médicos\Roy\INTECNUS---RoyQA\Medido Platform 2024 fotones\X6 ago2024 Perfiles y PDDs.asc'
measurement_file_path = r'P:\8 - Físicos Médicos\Roy\INTECNUS---RoyQA\Medido Synergy 2024\synergy2024electrones.csv'
# monaco_calculation_file_path = r'P:\8 - Físicos Médicos\Roy\INTECNUS---RoyQA\MONACO\SYNERGY\ELECTRONES\DFS 100\20x20\BLUEoELECoSYN.ELECoSYN.Transverse.0.00.1'.replace('\\','/')
# monaco_calculation_file_path = r'P:\8 - Físicos Médicos\Roy\INTECNUS---RoyQA\MONACO\SYNERGY\X06\DFS 100\30x30\BLUEx06oSYN.FotonesX06SYN.Coronal.150.00.4'.replace('\\','/')
meas_curves = import_measured_curves(measurement_file_path)
# calc_curves = import_calculated_curves(monaco_calculation_file_path, machine='S')

print('Medido:')

plt.figure()
for curve in meas_curves:
    print_curve_data(curve)
    if curve.field_size == 20.0 and curve.date.split('/')[2] == '2024' and curve.coordinate == 'Z':
        
        
        # if curve.coordinate == 'X':
        # i_max = curve.relative_dose.argmax()
        # print(curve.relative_dose[i_max])
        # print(curve.axis[i_max])
        
        plt.plot(curve.axis,curve.relative_dose, label=curve.coordinate)
    
        # plt.grid()
        # plt.legend()
        # if curve.coordinate != 'Z':
            # plt.ylim(48,52)
            # plt.xlim(-160,160)

plt.grid()
plt.legend()
plt.show()

# print('Calculado:')
# for curve in calc_curves:
#     print_curve_data(curve)

#     plt.figure()
#     plt.plot(curve.axis,curve.relative_dose, marker='.')
#     plt.show
# Out:
# Medido:
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:18:56, Particula:   1, Energia:     6.0, DFS:         100.0, TC:          20.0, Coordenada:  X, Profundidad: 18.3, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:20:40, Particula:   1, Energia:     6.0, DFS:         100.0, TC:          20.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:21:08, Particula:   1, Energia:     6.0, DFS:         100.0, TC:          20.0, Coordenada:  Y, Profundidad: 18.3, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:22:23, Particula:   1, Energia:     9.0, DFS:         100.0, TC:          20.0, Coordenada:  X, Profundidad: 28.1, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:24:55, Particula:   1, Energia:     9.0, DFS:         100.0, TC:          20.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:25:33, Particula:   1, Energia:     9.0, DFS:         100.0, TC:          20.0, Coordenada:  Y, Profundidad: 28.1, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:26:48, Particula:   1, Energia:     12.0, DFS:         100.0, TC:          20.0, Coordenada:  X, Profundidad: 39.4, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:28:52, Particula:   1, Energia:     12.0, DFS:         100.0, TC:          20.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:29:35, Particula:   1, Energia:     12.0, DFS:         100.0, TC:          20.0, Coordenada:  Y, Profundidad: 39.4, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:30:51, Particula:   1, Energia:     15.0, DFS:         100.0, TC:          20.0, Coordenada:  X, Profundidad: 47.4, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:32:56, Particula:   1, Energia:     15.0, DFS:         100.0, TC:          20.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:33:44, Particula:   1, Energia:     15.0, DFS:         100.0, TC:          20.0, Coordenada:  Y, Profundidad: 47.4, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:34:59, Particula:   1, Energia:     6.0, DFS:         100.0, TC:          6.0, Coordenada:  X, Profundidad: 18.3, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:46:10, Particula:   1, Energia:     6.0, DFS:         100.0, TC:          6.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:46:29, Particula:   1, Energia:     6.0, DFS:         100.0, TC:          6.0, Coordenada:  Y, Profundidad: 18.3, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:47:08, Particula:   1, Energia:     9.0, DFS:         100.0, TC:          6.0, Coordenada:  X, Profundidad: 28.1, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:48:41, Particula:   1, Energia:     9.0, DFS:         100.0, TC:          6.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:49:06, Particula:   1, Energia:     9.0, DFS:         100.0, TC:          6.0, Coordenada:  Y, Profundidad: 28.1, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:56:57, Particula:   1, Energia:     12.0, DFS:         100.0, TC:          6.0, Coordenada:  X, Profundidad: 39.4, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:57:35, Particula:   1, Energia:     12.0, DFS:         100.0, TC:          6.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:58:02, Particula:   1, Energia:     12.0, DFS:         100.0, TC:          6.0, Coordenada:  Y, Profundidad: 39.4, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        14:58:42, Particula:   1, Energia:     15.0, DFS:         100.0, TC:          6.0, Coordenada:  X, Profundidad: 47.4, Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        15:00:19, Particula:   1, Energia:     15.0, DFS:         100.0, TC:          6.0, Coordenada:  Z, Profundidad: , Detector:    CC13SN14317
# Equipo:      S, Fecha:       19/05/2024, Hora:        15:00:49, Particula:   1, Energia:     15.0, DFS:         100.0, TC:          6.0, Coordenada:  Y, Profundidad: 47.4, Detector:    CC13SN14317
